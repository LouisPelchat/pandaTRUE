# %% [markdown]
# # Titre de mon carnet

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib as mp

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-f918f5128e0e> in <module>()
# ----> 1 pd.set_option("display.float.format")
#
# /home/ubuntu/miniconda3/envs/brassens/lib/python3.6/site-packages/pandas/core/config.py in __call__(self, *args, **kwds)
#     221
#     222     def __call__(self, *args, **kwds):
# --> 223         return self.__func__(*args, **kwds)
#     224
#     225     @property
#
# /home/ubuntu/miniconda3/envs/brassens/lib/python3.6/site-packages/pandas/core/config.py in _set_option(*args, **kwargs)
#     106     nargs = len(args)
#     107     if not nargs or nargs % 2 != 0:
# --> 108         raise ValueError("Must provide an even number of non-keyword "
#     109                          "arguments")
#     110
#
# ValueError: Must provide an even number of non-keyword arguments

# %%
md = pd.read_csv("cnq.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-454c38a24588> in <module>()
# ----> 1 md = pd.read_csv("cnq.csv")
#
# ...

# %%
md = pd.read_csv("cmq.csv")

# %%
md
# Out:
#           num  annee                       prenom                nom genre  \
# 0      #30001   1930                       Lucien              Amyot     M
# 1      #30002   1930                      Wilfrid              Audet     M
# 2      #30003   1930                        A. T.            Batshaw     M
# 3      #30005   1930                      Maurice            Beaudry     M
# 4      #30006   1930                        P. E.            Belleau     M
# 5      #30008   1930                       Antoni              Blais     M
# 6      #30012   1930                         Lyla              Brown     F
# 7      #30014   1930                     Alphonse          Couturier     M
# 8      #30015   1930                          Guy       D'Argencourt     M
# 9      #30017   1930                         Rémi         Desjardins     M
# 10     #30020   1930                       Armand           Frappier     M
# ...

# %%
md.shape
# Out:
# (35109, 14)

# %%
md.loc[600:612], "nom", "prenom", "num"
# Out:
# (        num  annee      prenom        nom genre  \
#  600  #40064   1940      Irènée    Leblanc     M
#  601  #40065   1940  Georges E.     Lemyre     M
#  602  #40066   1940      Gérard    Leonard     M
#  603  #40067   1940   Robert D.    Lessard     M
#  604  #40069   1940        Jean    Lorrain     M
#  605  #40071   1940       Roger    Lussier     M
#  606  #40072   1940   Donald W.  Macmillan     M
#  607  #40073   1940  Jean Eudes    Maguire     M
#  608  #40074   1940       H. I.  Mendelson     M
#  609  #40075   1940     Lasalle     Mondor     M
#  610  #40076   1940   Jean-Marc      Morin     M
#  611  #40077   1940     Solomon      Ostro     M
#  612  #40079   1940      Marcel  Plamondon     M
#
#                                             specialite1      specialite2  \
#  600                                Médecine de famille              NaN
#  601                                Médecine de famille              NaN
# ...

# %%
md.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-82ae99edf68b> in <module>()
# ----> 1 md.colums
#
# /home/ubuntu/miniconda3/envs/brassens/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'colums'

# %%
md.columns
# Out:
# Index(['num', 'annee', 'prenom', 'nom', 'genre', 'specialite1', 'specialite2',
#        'specialite3', 'statut', 'dateChangStatut', 'typePermis', 'ville',
#        'prov', 'pays'],
#       dtype='object')

# %%
md.columns= ['num', 'annee', 'prenom', 'nom', 'genre', 'specialite1', 'specialite2',
       'specialite3', 'statut', 'Date', 'Permis', 'ville',
       'prov', 'pays']

# %%
md.columns
# Out:
# Index(['num', 'annee', 'prenom', 'nom', 'genre', 'specialite1', 'specialite2',
#        'specialite3', 'statut', 'Date', 'Permis', 'ville', 'prov', 'pays'],
#       dtype='object')

# %%
md.dtypes
# Out:
# num            object
# annee           int64
# prenom         object
# nom            object
# genre          object
# specialite1    object
# specialite2    object
# specialite3    object
# statut         object
# Date           object
# Permis         object
# ville          object
# prov           object
# pays           object
# dtype: object

# %%
md.count()
# Out:
# num            35109
# annee          35109
# prenom         35108
# nom            35109
# genre          35109
# specialite1    35109
# specialite2     3467
# specialite3      224
# statut         35109
# Date           11412
# Permis         35109
# ville          33715
# prov           34133
# pays           35109
# dtype: int64

# %%
md.genre
# Out:
# 0        M
# 1        M
# 2        M
# 3        M
# 4        M
# 5        M
# 6        F
# 7        M
# 8        M
# 9        M
# 10       M
# 11       M
# 12       M
# 13       M
# 14       M
# 15       M
# 16       M
# 17       M
# 18       M
# 19       M
# 20       F
# 21       M
# 22       M
# 23       M
# 24       M
# 25       M
# 26       M
# 27       M
# 28       M
# 29       M
#         ..
# 35079    F
# 35080    F
# 35081    F
# 35082    M
# 35083    F
# 35084    M
# 35085    M
# 35086    F
# 35087    M
# 35088    F
# 35089    F
# 35090    M
# 35091    F
# 35092    F
# 35093    M
# 35094    M
# 35095    F
# 35096    F
# 35097    F
# 35098    M
# 35099    M
# 35100    M
# 35101    M
# 35102    F
# 35103    M
# 35104    M
# 35105    M
# 35106    F
# 35107    F
# 35108    M
# Name: genre, dtype: object

# %%
mil = pd.read_csv("militaires.csv")

# %%
mil
# Out:
#        annee  trimestre        date  \
# 0       2004          1  01-04-2004
# 1       2004          1  01-04-2004
# 2       2004          1  01-04-2004
# 3       2004          1  01-04-2004
# 4       2004          1  01-04-2004
# 5       2004          1  01-04-2004
# 6       2004          1  01-04-2004
# 7       2004          1  01-04-2004
# 8       2004          1  01-04-2004
# 9       2004          1  01-04-2004
# 10      2004          1  01-04-2004
# 11      2004          1  01-04-2004
# 12      2004          1  01-04-2004
# 13      2004          1  01-04-2004
# 14      2004          1  01-04-2004
# 15      2004          1  01-04-2004
# 16      2004          1  01-04-2004
# 17      2004          1  01-04-2004
# 18      2004          1  01-04-2004
# 19      2004          1  01-04-2004
# 20      2004          1  01-04-2004
# 21      2004          1  01-04-2004
# 22      2004          1  01-04-2004
# 23      2004          1  01-04-2004
# 24      2004          1  01-04-2004
# ...

# %%
mil.montant.max
# Out:
# <bound method Series.max of 0        1200000.00
# 1          49382.00
# 2          50000.00
# 3          24000.00
# 4         250528.00
# 5          11834.00
# 6          29775.00
# 7         162329.00
# 8         178333.00
# 9          61810.00
# 10         43121.00
# 11         19029.00
# 12        224700.00
# 13         12426.00
# 14        239941.00
# 15         35310.00
# 16         47315.00
# 17         59706.00
# 18         26168.00
# 19        359646.00
# 20        674314.00
# 21         17604.00
# 22        448375.00
# 23        217816.00
# 24         80250.00
# 25        283000.00
# 26         11079.00
# 27         14439.00
# 28         14989.00
# 29         15921.00
#             ...
# 13548      92525.00
# 13549      22643.00
# 13550     629470.00
# 13551     156843.00
# 13552      51554.00
# 13553     188800.00
# 13554     299270.00
# 13555      12892.59
# 13556      24297.00
# 13557      10446.38
# 13558      11155.40
# 13559      59999.64
# 13560      19037.10
# ...

# %%
mil.montant.max
# Out:
# <bound method Series.max of 0        1200000.00
# 1          49382.00
# 2          50000.00
# 3          24000.00
# 4         250528.00
# 5          11834.00
# 6          29775.00
# 7         162329.00
# 8         178333.00
# 9          61810.00
# 10         43121.00
# 11         19029.00
# 12        224700.00
# 13         12426.00
# 14        239941.00
# 15         35310.00
# 16         47315.00
# 17         59706.00
# 18         26168.00
# 19        359646.00
# 20        674314.00
# 21         17604.00
# 22        448375.00
# 23        217816.00
# 24         80250.00
# 25        283000.00
# 26         11079.00
# 27         14439.00
# 28         14989.00
# 29         15921.00
#             ...
# 13548      92525.00
# 13549      22643.00
# 13550     629470.00
# 13551     156843.00
# 13552      51554.00
# 13553     188800.00
# 13554     299270.00
# 13555      12892.59
# 13556      24297.00
# 13557      10446.38
# 13558      11155.40
# 13559      59999.64
# 13560      19037.10
# ...

# %%
mil.montant.max(
)
# Out:
# 9500000.0

# %%
mil.montant.mean()
# Out:
# 152063.05036897922

# %%
md.genre.value_counts()
# Out:
# M    22441
# F    12668
# Name: genre, dtype: int64

# %%
md.genre.value_counts()/ len(md.genre)
# Out:
# M    0.639181
# F    0.360819
# Name: genre, dtype: float64

# %%
md.genre.value_counts()/ len(md.genre)*100
# Out:
# M    63.918084
# F    36.081916
# Name: genre, dtype: float64

# %%
md.nom.value_counts()
# Out:
# Roy                239
# Gagnon             224
# Tremblay           208
# Nguyen             207
# Côté               189
# Morin              140
# Gauthier           128
# Fortin             120
# Bouchard           119
# Pelletier          117
# Lavoie             111
# Bergeron           110
# Bélanger           100
# Leblanc             95
# Lapointe            91
# Simard              89
# Boucher             87
# Lévesque            86
# Caron               86
# Ouellet             85
# Lessard             84
# Nadeau              80
# Gagné               79
# Girard              77
# Martin              76
# Beaulieu            76
# Landry              75
# Bédard              74
# Leclerc             73
# Lemieux             72
#                   ...
# Ferragne             1
# Elias Lopez          1
# Cata                 1
# Man-Son-Hing         1
# Irving               1
# Bernath              1
# Angliker             1
# Kotwall              1
# Warkus               1
# ...

# %%
mil.columns
# Out:
# Index(['annee', 'trimestre', 'date', 'fournisseur', 'description', 'montant'], dtype='object')

# %%
mil.fournisseur.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                                    JOHNSON CONTROLS LTD.
# 1                                      Hewitt Rentals Inc.
# 2                             marlene hurley brandy hurley
# 3                                       Levitt-Safety Ltd.
# 4                                       I S E Research Ltd
# 5                                               Cyberguard
# 6                                   LOS ALTOS TECHNOLOGIES
# 7                                       FOSTER-MILLER INC.
# 8                                     EADS Astrium Limited
# 9        Ranco Controls Canada Limited, CompAir Canada ...
# 10                                         BDI Canada  Inc
# 11                                          Nautel Limited
# 12                                Edmonton Gear Centre Ltd
# 13                                 A P M DIESEL (1992) INC
# 14                 DEW Engineering and Development Limited
# ...

# %%
mil.groupby("fournisseur").montant.sum().sort_values(ascending=False)
# Out:
# fournisseur
# UNITED STATES DEPARTMENT OF THE AIR FORCE (AFSAC)             18458629.00
# Skylink Aviation Inc                                          18429545.14
# SkyLink Aviation Inc.                                         18091044.31
# SKYLINK AVIATION                                              17559538.80
# SIMEX DEFENCE INC. / DEFENSE SIMEX INC.                       16242356.00
# UNITED STATES DEPARTMENT OF THE ARMY (USASAC)                 15741157.00
# Calian Ltd                                                    15244855.53
# SkyLink Aviation                                              13431716.30
# Hewlett-Packard (Canada) Co. Hewlett-Packard (Canada) Cie     12727054.00
# UNITED STATES DEPARTMENT OF THE AIR FORCE (AFSAT)             11819634.00
# Caspian Projects Inc                                          11579442.00
# THALES CANADA INC.                                            11341356.00
# ...

# %%
md.statut.value_counts()
# Out:
# Inscrit - Actif                                            21017
# Démission                                                   4623
# Retrait pour décès                                          3877
# Inscrit - Retraité                                          2415
# Radié pour non paiement de cotisation                       2085
# Expiration                                                   630
# Inscrit - Actif (l'exercice de ce membre est limité)         184
# Radié pour non-paiement de cotisation                         88
# Inscrit - Retraité (l'exercice de ce membre est limité)       71
# Radié                                                         67
# Retrait                                                       29
# Inscrit - Inactif                                             10
# Non inscrit                                                    9
# Révocation                                                     4
# Name: statut, dtype: int64

# %%
rad = md.statut == "Radié"  
md[rad]
# Out:
#           num  annee       prenom            nom genre  \
# 1375   #48004   1948     Alphonse        Bardari     M
# 1661   #49130   1949      Jacques      Pettigrew     M
# 2512   #53150   1953        J.-C.       Paquette     M
# 2761   #54174   1954     Philippe       Moreault     M
# 3057   #55201   1955       Claude  Saint-Laurent     M
# 3087   #55234   1955      Thérèse        Leclerc     F
# 3253   #56099   1956      Gilbert        Michaud     M
# 4220   #59188   1959        Lloyd         Alford     M
# 4483   #60125   1960      Jeannot          Houle     M
# 4801   #61113   1961      Noël R.       Kaufmann     M
# 4840   #61157   1961         Jack           Blum     M
# 4957   #61325   1961       Gérard       Monfette     M
# 5129   #62157   1962       Andrée        Lessard     F
# 5250   #62290   1962         Yvon       Scheffer     M
# 5590   #63290   1963  Albert Ross           Deep     M
# 6096   #65137   1965       Claude        Leclair     M
# ...

# %%
md[rad].genre.value_counts()
# Out:
# M    61
# F     6
# Name: genre, dtype: int64

# %%
drLab= md.nom == "Labrèche"

# %%
md[drLab]
# Out:
#           num  annee   prenom       nom genre         specialite1 specialite2  \
# 23527  #97250   1997  Jacques  Labrèche     M  Chirurgie générale         NaN
#
#       specialite3           statut Date    Permis          ville    prov  \
# 23527         NaN  Inscrit - Actif  NaN  Régulier  Drummondville  Québec
#
#          pays
# 23527  Canada

# %%
md.pays.value_counts()
# Out:
# Canada                 32737
# États-Unis              1405
# Inconnu                  608
# France                    78
# Royaume-Uni               68
# Liban                     35
# Suisse                    20
# Espagne                   15
# Australie                 12
# Israël                    11
# Irlande                    9
# Allemagne                  8
# Émirats arabes unis        8
# Haïti                      6
# Mexique                    5
# Arabie Saoudite            5
# Kenya                      5
# Nouvelle-Zélande           4
# Brésil                     4
# Hong Kong                  4
# Inde                       4
# Italie                     3
# Belgique                   3
# Syrie                      3
# Afrique du Sud             3
# Singapour                  3
# Chine                      3
# Bermudes                   3
# Danemark                   2
# Barbade                    2
# Grèce                      2
# Pays-Bas                   2
# ...

# %%
actifs = md.statut.str.contains("Actif")

# %%
md.pays.value_counts()
# Out:
# Canada                 20973
# États-Unis               162
# France                    17
# Liban                     11
# Suisse                     6
# Émirats arabes unis        5
# Bermudes                   3
# Australie                  3
# Afrique du Sud             2
# Israël                     2
# Haïti                      2
# Royaume-Uni                2
# Chine                      2
# Brésil                     1
# Nouvelle-Zélande           1
# Cambodge                   1
# Singapour                  1
# Barbade                    1
# Îles Cayman                1
# Arabie Saoudite            1
# Syrie                      1
# Kenya                      1
# Irlande                    1
# Maroc                      1
# Name: pays, dtype: int64

# %%
famille = [actifs]md.specialite1 == "Médecine de famille"

# %% [markdown]
# md[famille]

# %%
md[actifs][famille]
# Out:
# /home/ubuntu/miniconda3/envs/brassens/lib/python3.6/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#           num  annee                  prenom                nom genre  \
# 4181   #59140   1959                   Henri              Lecoq     M
# 4284   #59258   1959                Erwin B.            Nichols     M
# 4384   #60023   1960                  Gilles              Aubin     M
# 4476   #60118   1960              Paul-Émile              Godin     M
# 4481   #60123   1960                  Paulin             Hébert     M
# 4487   #60130   1960                  Michel              Jobin     M
# 4499   #60142   1960                Léo-Yves            Lamarre     M
# 4575   #60222   1960                     Guy            Rondeau     M
# 4585   #60233   1960                Fernande       Soucy-Hirtle     F
# 4773   #61082   1961               Jean-Léon             Éthier     M
# ...

# %%
md[actifs][famille].genre.value_counts()
# Out:
# /home/ubuntu/miniconda3/envs/brassens/lib/python3.6/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
# F    5610
# M    4497
# Name: genre, dtype: int64

# %%
avant1960 = md.annee < 1960

# %%
md[avant1960]
# Out:
#          num  annee                 prenom           nom genre  \
# 0     #30001   1930                 Lucien         Amyot     M
# 1     #30002   1930                Wilfrid         Audet     M
# 2     #30003   1930                  A. T.       Batshaw     M
# 3     #30005   1930                Maurice       Beaudry     M
# 4     #30006   1930                  P. E.       Belleau     M
# 5     #30008   1930                 Antoni         Blais     M
# 6     #30012   1930                   Lyla         Brown     F
# 7     #30014   1930               Alphonse     Couturier     M
# 8     #30015   1930                    Guy  D'Argencourt     M
# 9     #30017   1930                   Rémi    Desjardins     M
# 10    #30020   1930                 Armand      Frappier     M
# 11    #30021   1930                 Edmour      Frenette     M
# 12    #30024   1930                  I. M.      Gauthier     M
# 13    #30028   1930                  J. A.        Hébert     M
# ...

# %%
md[famille & actifs].genre.value_counts()
# Out:
# F    5610
# M    4497
# Name: genre, dtype: int64

# %%
md[famille & actifs].genre.value_counts().plot()

# %%
md[famille & actifs].genre.value_counts().plot(kind="pie")

# %%
md[famille & actifs].genre.value_counts().plot(kind="bar", title="Nice graph")

# %%
md.annee.hist()

# %%
md.annee.hist(bins=87)

# %%
md.groupby("genre").annee.hist(bins=87, alpha= 0.5)
# Out:
# genre
# F    Axes(0.125,0.125;0.775x0.755)
# M    Axes(0.125,0.125;0.775x0.755)
# Name: annee, dtype: object

# %%
mil.groupby("annee").montant.sum()
# Out:
# annee
# 2004    2.669878e+08
# 2005    3.897053e+08
# 2006    1.936317e+08
# 2007    1.189116e+08
# 2008    6.558974e+07
# 2009    8.243240e+07
# 2010    5.385913e+07
# 2011    2.023364e+08
# 2012    1.212093e+08
# 2013    1.528981e+08
# 2014    6.264056e+07
# 2015    2.487403e+08
# 2016    1.057698e+08
# Name: montant, dtype: float64

# %%
mil.groupby("annee").montant.sum().plot()

# %%
mil.groupby("annee").montant.sum().plot(kind= "barh", color= "salmon")
